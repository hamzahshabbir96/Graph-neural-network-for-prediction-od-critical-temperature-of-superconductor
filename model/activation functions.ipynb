# %% [markdown]
# # Activation functions

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import pyplot
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# %%
def sigmoid(x):

    return 1/(1+np.exp(-x))

def relu(x):
    
    x1=[]
    for i in x:
        if i<0:
            x1.append(0)
        else:
            x1.append(i)

    return x1
def lrelu(x):
    ''' It returns zero if the input is less than zero otherwise it returns the given input. '''
    x1=[]
    for i in x:
        if i<0:
            x1.append(0.01*i)
        else:
            x1.append(i)

    return x1

# %%
x = np.linspace(-10, 10)

fig, ax = plt.subplots(figsize=(10, 7))
#plt.rcParams.update({'font.size': 20})
plt.xticks(rotation=90,size =16)
ax.plot(x, sigmoid(x),color="brown")
plt.axvline(x=0, c="black", label="x=0")
plt.axhline(y=0, c="black", label="y=0")
ax.set_ylabel('f(x)',fontsize=20)
ax.set_xlabel('x',fontsize=20)
#ax2.set_title('Pareto chart',fontsize=20)
ax.tick_params(axis="y", colors="black")

plt.savefig('sigmoid.jpg', 
                          dpi=300,
                          facecolor='w',
                          edgecolor='w',
                          orientation='portrait',
                          papertype=None, 
                          format="jpg",
                          transparent=False,
                          bbox_inches="tight", 
                          pad_inches=0,
                          frameon=None, 
                          metadata=None)

plt.show()
# Out:
# <ipython-input-3-478e36c646e0>:14: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('sigmoid.jpg',
# <ipython-input-3-478e36c646e0>:14: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('sigmoid.jpg',
# <ipython-input-3-478e36c646e0>:14: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "metadata" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('sigmoid.jpg',

# %%
x = np.linspace(-10, 10)

fig, ax = plt.subplots(figsize=(10, 7))
#plt.rcParams.update({'font.size': 20})
plt.xticks(rotation=90,size =16)
ax.plot(x, relu(x),color="brown")
plt.axvline(x=0, c="black", label="x=0")
plt.axhline(y=0, c="black", label="y=0")
ax.set_ylabel('f(x)',fontsize=20)
ax.set_xlabel('x',fontsize=20)
#ax2.set_title('Pareto chart',fontsize=20)
ax.tick_params(axis="y", colors="black")

plt.savefig('relu.jpg', 
                          dpi=300,
                          facecolor='w',
                          edgecolor='w',
                          orientation='portrait',
                          papertype=None, 
                          format="jpg",
                          transparent=False,
                          bbox_inches="tight", 
                          pad_inches=0,
                          frameon=None, 
                          metadata=None)

plt.show()
# Out:
# <ipython-input-4-fde21c8917ae>:14: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('relu.jpg',
# <ipython-input-4-fde21c8917ae>:14: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('relu.jpg',
# <ipython-input-4-fde21c8917ae>:14: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "metadata" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('relu.jpg',

# %%
x = np.linspace(-10, 10)

fig, ax = plt.subplots(figsize=(10, 7))
#plt.rcParams.update({'font.size': 20})
plt.xticks(rotation=90,size =16)

plt.axvline(x=0, c="black", label="x=0")
plt.axhline(y=0, c="black", label="y=0")

ax.plot(x, lrelu(x),color="brown")

ax.set_ylabel('f(a)',fontsize=20)
ax.set_xlabel('a',fontsize=20)
#ax2.set_title('Pareto chart',fontsize=20)
ax.tick_params(axis="y", colors="black")

plt.savefig('lrelu.jpg', 
                          dpi=300,
                          facecolor='w',
                          edgecolor='w',
                          orientation='portrait',
                          papertype=None, 
                          format="jpg",
                          transparent=False,
                          bbox_inches="tight", 
                          pad_inches=0,
                          frameon=None, 
                          metadata=None)

plt.show()
# Out:
# <ipython-input-5-5d45a223dab1>:17: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('lrelu.jpg',
# <ipython-input-5-5d45a223dab1>:17: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('lrelu.jpg',
# <ipython-input-5-5d45a223dab1>:17: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "metadata" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('lrelu.jpg',
